# %% [markdown]
# This notebook shows you how you can easily load the pre-trained BERT2BERT model for empathetic response generation in Arabic and use it to generate response on your input.

# %%
#Install dependencies
# !pip install transformers
# !pip install pyarabic
# !pip install farasapy
# !git clone https://github.com/aub-mind/arabert
# Out:
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ---------------------------------------- 7.1/7.1 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (1.24.1)
# Collecting regex!=2019.12.17
#   Downloading regex-2023.5.5-cp39-cp39-win_amd64.whl (267 kB)
#      -------------------------------------- 268.0/268.0 KB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (4.65.0)
# Collecting huggingface-hub<1.0,>=0.14.1
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      -------------------------------------- 224.5/224.5 KB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (23.1)
# Requirement already satisfied: filelock in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 3.5/3.5 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.6.2)
# Collecting fsspec
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      -------------------------------------- 160.1/160.1 KB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->transformers) (3.1.0)
# Installing collected packages: tokenizers, regex, fsspec, huggingface-hub, transformers
# Successfully installed fsspec-2023.5.0 huggingface-hub-0.14.1 regex-2023.5.5 tokenizers-0.13.3 transformers-4.29.2
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Fastora\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting pyarabic
#   Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#      -------------------------------------- 126.4/126.4 KB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.14.0 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from pyarabic) (1.16.0)
# Installing collected packages: pyarabic
# Successfully installed pyarabic-0.6.15
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Fastora\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# Collecting farasapy
#   Downloading farasapy-0.0.14-py3-none-any.whl (11 kB)
# Requirement already satisfied: tqdm in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from farasapy) (4.65.0)
# Requirement already satisfied: requests in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from farasapy) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->farasapy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->farasapy) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->farasapy) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from requests->farasapy) (3.4)
# Requirement already satisfied: colorama in c:\users\fastora\appdata\local\programs\python\python39\lib\site-packages (from tqdm->farasapy) (0.4.6)
# Installing collected packages: farasapy
# Successfully installed farasapy-0.0.14
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Fastora\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# fatal: destination path 'arabert' already exists and is not an empty directory.

# %%
#Import transformers
import transformers

# %%
#Load arabert preprocessor
from arabert.preprocess import ArabertPreprocessor
arabert_prep = ArabertPreprocessor(model_name="bert-base-arabert", keep_emojis=False)

# %%
#Load Model
from transformers import EncoderDecoderModel, AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("tareknaous/bert2bert-empathetic-response-msa")
model = EncoderDecoderModel.from_pretrained("tareknaous/bert2bert-empathetic-response-msa")

model.to("cuda")
model.eval()
print("done")
# Out:
# done

# %%
#Function to generater response/post-process
def generate_response(text):
  text_clean = arabert_prep.preprocess(text)
  inputs = tokenizer.encode_plus(text_clean,return_tensors='pt')
  outputs = model.generate(input_ids = inputs.input_ids.to("cuda"),
                   attention_mask = inputs.attention_mask.to("cuda"),
                   num_beams=1,
                   do_sample = True,
                   min_length=10,
                   top_k = 50,
                   temperature = 1,
                   length_penalty =2)
  preds = tokenizer.batch_decode(outputs) 
  response = str(preds)
  response = response.replace("\'", '')
  response = response.replace("[[CLS]", '')
  response = response.replace("[SEP]]", '')
  response = str(arabert_prep.desegment(response))
  return response

# %%
#Trial
text =  "الله يلعن هالبلد انقطعت الكهربا !"
generate_response(text)
# Out:
# ' بالطبع ، لم يكن علي كالذهاب إلى المدرسة من قبل '
